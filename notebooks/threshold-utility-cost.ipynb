# %%
from equalityml import FAIR, discrimination_threshold, paired_ttest, binary_threshold_score
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.metrics import accuracy_score, f1_score
from sklearn.base import clone
import numpy as np
import pandas as pd
import warnings

# %matplotlib inline
random_seed = 0

# %% [markdown]
# ### 1. Train a Machine Learning Model

# %%
# Dataset Parameters
target_var = 'two_year_recid'
features = ['juv_fel_count', 'decile_score', 'juv_misd_count', 'juv_other_count', 'priors_count', 'sex', 'age']

# %%
data = pd.read_csv('../data/compas-scores-two-years.csv')

# %%
y = data[target_var]
X = data[features]

# %%
X.head()
# Out:
#    juv_fel_count  decile_score  juv_misd_count  juv_other_count  priors_count  \
# 0              0             1               0                0             0
# 1              0             3               0                0             0
# 2              0             4               0                1             4
# 3              0             8               1                0             1
# 4              0             1               0                0             2
#
#     sex  age
# 0  Male   69
# 1  Male   34
# 2  Male   24
# 3  Male   23
# 4  Male   43

# %%
# Define which columns should be encoded
columns_to_encode = ['sex']

# Instantiate encoder
ohe = OneHotEncoder(sparse=False, drop = 'if_binary')

# Scale 
encoded_data = ohe.fit_transform(X[columns_to_encode])

# Concatenate (Column-Bind) Processed Columns Back Together
encoded_df = pd.DataFrame(encoded_data, columns = columns_to_encode)

processed_data = pd.concat([X.drop(columns=columns_to_encode), encoded_df], axis=1)
processed_data = pd.DataFrame(processed_data, columns = X.columns)

# %%
processed_data.head()
# Out:
#    juv_fel_count  decile_score  juv_misd_count  juv_other_count  priors_count  \
# 0              0             1               0                0             0
# 1              0             3               0                0             0
# 2              0             4               0                1             4
# 3              0             8               1                0             1
# 4              0             1               0                0             2
#
#    sex  age
# 0  1.0   69
# 1  1.0   34
# 2  1.0   24
# 3  1.0   23
# 4  1.0   43

# %%
# Training and testing dataset split
X_train, X_test, y_train, y_test = train_test_split(processed_data, y, test_size=0.2, random_state=random_seed)

# %%
# Train a machine learning model (for example LogisticRegression)
orig_ml_model = LogisticRegression()
orig_ml_model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
testing_data = pd.concat([X_test, y_test], axis=1)
training_data = pd.concat([X_train, y_train], axis=1)

# %% [markdown]
# ### 2. Optimal Discrimination Threshold for Utility Cost

# %%
decision_maker = ['cost', 'max']
scoring = "cost"
utility_costs=[1, -0.3, -1, 0.3]
# Discrimination Threshold
threshold = discrimination_threshold(orig_ml_model, 
                                     target_var,
                                     training_data=training_data,
                                     testing_data=testing_data,
                                     decision_maker=decision_maker,
                                     metrics=[decision_maker[0]], 
                                     utility_costs=utility_costs,
                                     show=True,
                                     random_seed=random_seed)
print(f"Discrimination Threshold = {threshold:.3f}")
# Out:
# 100%|██████████| 10/10 [00:01<00:00,  7.97it/s]
# Discrimination Threshold = 0.485

# %%
orig_cost = binary_threshold_score(orig_ml_model, 
                                   X_test, 
                                   y_test,
                                   scoring=scoring,
                                   threshold=threshold,
                                   utility_costs=utility_costs)
print(f"Original cost = {orig_cost:.3f}")
# Out:
# Original cost = 298.400

# %% [markdown]
# ### 3. Fairness Metric Assessment

# %%
#Instantiate FAIR object
fair_object = FAIR(ml_model=orig_ml_model,
                   training_data=training_data,
                   testing_data=testing_data, 
                   target_variable=target_var,
                   protected_variable="sex", 
                   privileged_class=1.0,
                   threshold=threshold,
                   random_seed=random_seed)

# %%
metric_name='statistical_parity_ratio'
orig_fairness_metric_score = fair_object.fairness_metric(metric_name)
print(f"Original Fairness Metric = {orig_fairness_metric_score:.3f}")
# Out:
# Original Fairness Metric = 0.434

# %% [markdown]
# ### 4. Compare Performance of Each Mitigation Method

# %%
# Print available bias mitigation methods for statistical_parity_ratio
fair_object.print_bias_mitigation_methods(metric_name)
# Out:
# Available bias mitigation methods for 'statistical_parity_ratio' are:
# 1 'disparate-impact-remover'
# 2 'resampling'
# 3 'resampling-preferential'
# 4 'reweighing'

# %%
df = fair_object.compare_mitigation_methods(metric_name=metric_name, 
                                            scoring=scoring, 
                                            utility_costs=utility_costs,
                                            show=True,
                                            compute_discrimination_threshold=True,
                                            decision_maker=decision_maker)
print(df)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 13.10it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.14it/s]
# 100%|██████████| 1/1 [00:00<00:00, 14.35it/s]
# 100%|██████████| 1/1 [00:00<00:00, 13.59it/s]
#                            cost  statistical_parity_ratio  \
# reference                 298.4                  0.434186
# disparate-impact-remover  311.4                  0.464819
# resampling                314.0                  0.908648
# resampling-preferential   290.6                  0.773537
# reweighing                314.0                  0.881557
#
#                           discrimination_threshold
# reference                                 0.484848
# disparate-impact-remover                  0.454545
# resampling                                0.424242
# resampling-preferential                   0.444444
# reweighing                                0.424242

# %% [markdown]
# ### 5. Apply Resampling Mitigation and Re-evaluate Utility Cost and Fairness Metric

# %%
mitigation_method = "resampling"
mitigation = fair_object.bias_mitigation(mitigation_method = mitigation_method)

# extract modified data 
X_train = mitigation['training_data'][features]
# drop y 
y_train = mitigation['training_data'][target_var]

# Train the second machine learning model using the mitigated dataset
ml_model = clone(orig_ml_model)
ml_model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
# We can also find the optimal discrimination threshold for this new model
threshold = discrimination_threshold(ml_model,
                                     target_var,
                                     testing_data=testing_data,
                                     decision_maker=decision_maker,
                                     metrics=[decision_maker[0]], 
                                     utility_costs=utility_costs,
                                     show=True,
                                     model_training=False,
                                     random_seed=random_seed)
print(f"Discrimination Threshold = {threshold:.3f}")
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 13.62it/s]
# Discrimination Threshold = 0.424

# %%
cost = binary_threshold_score(ml_model, 
                              X_test, 
                              y_test, 
                              scoring=scoring,
                              threshold=threshold,
                              utility_costs=utility_costs)
print(f"Mitigated cost = {cost:.3f}")
# Out:
# Mitigated cost = 314.000

# %%
#Instantiate FAIR object
fair_object = FAIR(ml_model=ml_model,
                   training_data=training_data,
                   testing_data=testing_data, 
                   target_variable=target_var,
                   protected_variable="sex", 
                   privileged_class=1.0,
                   threshold=threshold,
                   random_seed=random_seed)

# %%
fairness_metric_score = fair_object.fairness_metric(metric_name)
print(f"Mitigated Fairness Metric = {fairness_metric_score:.3f}")
# Out:
# Mitigated Fairness Metric = 0.951

# %%
print(f"Original cost = {orig_cost:.3f} and Mitigated cost = {cost:.3f}")
print(f"Orginal Fairness Score = {orig_fairness_metric_score:.3f} and Mitigated Fairness Score = {fairness_metric_score:.3f}")
# Out:
# Original cost = 298.400 and Mitigated cost = 314.000
# Orginal Fairness Score = 0.434 and Mitigated Fairness Score = 0.951

# %% [markdown]
# ### 6. Paired t Test

# %%
# Paired t test between original Machine Learning model and "appyling the mitigation method".
# Fairness metric comparison
results = paired_ttest(orig_ml_model,
                        pd.concat([training_data, testing_data]),
                        target_var,
                        method="5x2cv",
                        threshold=threshold,
                        fair_object=fair_object,
                        mitigation_method=mitigation_method,
                        scoring=metric_name,
                        random_seed=random_seed)
print("5x2cv paired t-test using fairness metric. (chi2, p) =", results)
# Out:
# 100%|██████████| 5/5 [00:00<00:00,  5.16it/s]
# 5x2cv paired t-test using fairness metric. (chi2, p) = (-4.173974151334937, 0.008705513567415515)

# %%
# Paired t test between original Machine Learning model and "appyling the mitigation method".
# Cost comparison
results = paired_ttest(orig_ml_model,
                        pd.concat([training_data, testing_data]),
                        target_var,
                        method="5x2cv",
                        threshold=threshold,
                        fair_object=fair_object,
                        mitigation_method=mitigation_method,
                        scoring=scoring,
                        random_seed=random_seed)
print("5x2cv paired t-test using cost metric. (chi2, p) =", results)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/ds/y6b2_3k90_n_k48_vczpfbcc0000gn/T/ipykernel_10516/1564530930.py in <module>
#       1 # Paired t test between original Machine Learning model and "appyling the mitigation method".
#       2 # Cost comparison
# ----> 3 results = paired_ttest(orig_ml_model,
#       4                         pd.concat([training_data, testing_data]),
#       5                         target_var,
#
# ~/PycharmProjects/EqualityML/equalityml/stats.py in paired_ttest(model_1, data, target_variable, model_2, method, threshold, fair_object, mitigation_method, scoring, utility_costs, random_seed)
#      77                           threshold=threshold)
#      78     elif method == "5x2cv":
# ---> 79         chi2, p = paired_ttest_5x2cv(model_1,
#      80                                      X,
#      81                                      y,
#
# ~/PycharmProjects/EqualityML/equalityml/stats.py in paired_ttest_5x2cv(model_1, X, y, model_2, threshold, fair_object, mitigation_method, scoring, utility_costs, random_seed)
#     347         X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=randint)
#     348
# --> 349         score_diff_A = _score_diff(_model_1, _model_2, X_train, y_train, X_test, y_test)
#     350         score_diff_B = _score_diff(_model_1, _model_2, X_test, y_test, X_train, y_train)
#     351         mean_diff = (score_diff_A + score_diff_B) / 2.0
#
# ~/PycharmProjects/EqualityML/equalityml/stats.py in _score_diff(_model_1, _model_2, _X_train, _y_train, _X_test, _y_test)
#     307         # Train model 1 and get score 1
#     308         _model_1.fit(_X_train, _y_train)
# --> 309         score_1 = scorer(_model_1, _X_test, _y_test)
#     310
#     311         if apply_mitigation or fair_object is not None and scoring in fair_object.fairness_metrics_list:
#
# ~/PycharmProjects/EqualityML/equalityml/stats.py in scorer(model, x, y)
#     295     else:
#     296         def scorer(model, x, y):
# --> 297             return binary_threshold_score(model,
#     298                                           x,
#     299                                           y,
#
# ~/PycharmProjects/EqualityML/equalityml/threshold.py in binary_threshold_score(ml_model, X, y, scoring, threshold, utility_costs)
#     620     _pred_class = np.asarray(list(map(lambda x: 1 if x > threshold else 0, ml_model.predict_proba(X)[:, -1])))
#     621     if scoring.lower() == 'cost':
# --> 622         utility_costs = _check_utility_costs(utility_costs)
#     623         tn, fp, fn, tp = _confusion_matrix(y, _pred_class)
#     624         score = np.sum(np.array(utility_costs) * np.array([tp, fn, fp, tn]))
#
# ~/PycharmProjects/EqualityML/equalityml/threshold.py in _check_utility_costs(utility_costs)
#      24         if len(utility_costs) == 4 and all(isinstance(x, (int, float)) for x in utility_costs):
#      25             return utility_costs
# ---> 26     raise ValueError(f"Invalid utility costs {utility_costs}. It must be a list of 4 values for [TP FN FP TN]")
#      27
#      28
#
# ValueError: Invalid utility costs None. It must be a list of 4 values for [TP FN FP TN]
